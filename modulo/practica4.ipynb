# %% [markdown]
# # Práctica 4
#
# ---

# %% [markdown]
# ## Ejercicio: Juego de rol
#
# Crea un juego de rol en modo texto. El jugador es un mago que se puede desplazar por una mazmorra en dirección **norte**, **sur**, **este**, y **oeste**. En algunas circunstancias, las direcciones pueden no estar disponibles.
#
# Al entrar en cada sala, se mostrará una descripción del entorno del jugador, y los movimientos posibles. Algunas salas pueden contener **objetos** que se incorporarán automáticamente al inventario del mago. El juego termina al encontrar el *Cetro de Alexrod* y llegar a la salida.
#
# Esto sería un ejemplo del mapa, que como podrás observar es un diccionario de diccionarios:

# %%
MAPA = {
  'Entrada' : {
    'descripcion': 'Te encuentras en el exterior de la torre de Tchutul, al norte hay una puerta.',
    'norte'      : 'Pasillo'
  },
  'Pasillo' : {
    'descripcion': 'El pasillo es oscuro, oyes gritos y lamentos. Hay una espada en el suelo.',
    'norte'      : 'Salida',
    'este'       : 'Armeria',
    'sur'        : 'Entrada',
    'objeto'     : 'Espada'
  },
  'Armeria' : {
    'descripcion': '¡Lo encontraste! el cetro de Alexrod esta en el suelo',
    'oeste'      : 'Pasillo',
    'objeto'     : 'Cetro de Alexrod'
  },
  'Salida' : {
    'descripcion': 'Esta es la salida',
    'sur'        : 'Pasillo'
  }
}

# %% [markdown]
# **Desafío:** Amplía el mapa y añade enemigos en algunas salas. Las batallas se resolverán de forma automática tirando un dado (programa esta regla de la forma que más te guste).
